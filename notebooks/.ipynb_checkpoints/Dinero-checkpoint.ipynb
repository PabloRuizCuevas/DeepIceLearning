# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
path='/home/pablo/Documents/cuenta.csv'

# %%
df = pd.read_csv(path)
df
for i in range(df.shape[0]):
    df["Importe"][i]=df["Importe"][i].replace(',','.')
# Out:
# <ipython-input-169-f2917d774189>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Importe"][i]=df["Importe"][i].replace(',','.')

# %%
dates_list = [datetime.strptime(date,"%d/%m/%Y").date() for date in df["Fecha_Operación"]]

# %%
fig, ax = plt.subplots()

plt.plot(dates_list,df["Saldo"])
#every_nth = 30
#for n, label in enumerate(ax.yaxis.get_ticklabels()):
#    if n % every_nth != 0:
#        label.set_visible(False)
plt.show()

# %%
df["Saldo"][150]-df["Saldo"][0]
# Out:
# 2755.999999999999

# %%
2755 euros al año
# Out:
# 6013.8

# %%
2755/12
# Out:
# 229.58333333333334

# %%
229 euros al mes
# Out:
# 229.0

# %%
sum(saldo[saldo<0])/12
# Out:
# -700.4416666666666

# %%
plt.hist(saldo)
# Out:
# (array([ 12.,  11., 112.,   1.,  13.,   0.,   0.,   0.,   0.,   2.]),
#  array([-380., -242., -104.,   34.,  172.,  310.,  448.,  586.,  724.,
#          862., 1000.]),
#  <a list of 10 Patch objects>)

# %%
saldo=np.array([float(df["Importe"][i]) for i in range(151)])

# %%
dates_list[0]-dates_list[-1]
# Out:
# datetime.timedelta(days=363)

# %%
plt.plot([10561-n*230 for n in range(50)])
plt.plot([10561-n*430 for n in range(50)])
plt.plot([10561-n*430-3000 for n in range(50)])
plt.xlabel("Meses")
plt.ylabel('Euros')
# Out:
# Text(0, 0.5, 'Euros')

# %%
700 piso + comida al mes
420 sueldo
300 madre

# %%
6500/24
# Out:
# 270.8333333333333

# %%
rango=30
plt.plot([10561+n*(-700+420+300) for n in range(rango)],label="Ahora mismo")
plt.plot([10561+n*(-700+420+300-200) for n in range(rango)],label="Cambio casa")
plt.plot([10561+n*(-700+420+300-200-270) for n in range(rango)],label="Cambio casa+ aparatos")
plt.plot([10561-3000+n*(-700+420+300-200-270) for n in range(rango)],label="Cambio casa+ aparatos+ coche")
plt.plot([10561-3000+n*(-700+3*420+300-200-270) for n in range(rango)],label="Cambio casa+ aparatos+ coche+ trabajo decente")
plt.legend(loc ='best')
plt.xlabel("Meses")
plt.ylabel('Euros')
# Out:
# Text(0, 0.5, 'Euros')
