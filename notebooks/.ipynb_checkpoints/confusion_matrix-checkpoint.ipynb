# %%
print(__doc__)

import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix

# import some data to play with
iris = datasets.load_iris()
X = iris.data
y = iris.target
class_names = iris.target_names

# Split the data into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# Run classifier, using a model that is too regularized (C too low) to see
# the impact on the results
classifier = svm.SVC(kernel='linear', C=0.01).fit(X_train, y_train)

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(classifier, X_test, y_test,
                                 display_labels=class_names,
                                 cmap=plt.cm.Blues,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Confusion matrix, without normalization
# [[13  0  0]
#  [ 0 10  6]
#  [ 0  0  9]]
# Normalized confusion matrix
# [[1.   0.   0.  ]
#  [0.   0.62 0.38]
#  [0.   0.   1.  ]]

# %%
classifier
# Out:
# SVC(C=0.01, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [[10,0,1],[0,87,51],[32,0,29]]

df_cm = pd.DataFrame(array, range(3), range(3))
plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 20}) # font size

plt.show()

# %%
cascades=61
Long_DB=138
short_DB=11

cascades_pred=
cascades_pred=
short_DB_pred=

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [[10,0,1],[0,87,51],[32,0,29]]
df_cm = pd.DataFrame(array, index = [i for i in ["True: Long DB","short DB","Cascade"]],
                  columns = [i for i in  ["Pred: Long DB","short DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm, annot=True)
ax.set_ylim(0, 3)
# Out:
# (0, 3)

# %%
#normaliced in numbers
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [np.array([10,0,1])/short_DB,np.array([0,87,51])/Long_DB,np.array([32,0,29])/cascades]
df_cm = pd.DataFrame(array, index = [i for i in ["True: Long DB","short DB","Cascade"]],
                  columns = [i for i in  ["Pred: Long DB","short DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm,center=0, annot=True, cmap=sn.diverging_palette(220, 100, as_cmap=True))
ax.set_ylim(0, 3)
# Out:
# (0, 3)

# %%
#normaliced in predictions
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [np.array([10/42,0,1/81]),np.array([0,87/87,51/81]),np.array([32/42,0,29/81])]
df_cm = pd.DataFrame(array, index = [i for i in ["True: Long DB","short DB","Cascade"]],
                  columns = [i for i in  ["Pred: Long DB","short DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm,center=0, annot=True, cmap=sn.diverging_palette(220, 100, as_cmap=True))
ax.set_ylim(0, 3)
# Out:
# (0, 3)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

DB=short_DB+Long_DB

array = [np.array([97,52]),np.array([32,29])]
df_cm = pd.DataFrame(array, index = [i for i in ["True: DB","Cascade"]],
                  columns = [i for i in  ["Pred: DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm, annot=True,center=0)
ax.set_ylim(0, 2)
# Out:
# (0, 2)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

DB=short_DB+Long_DB

array = [np.array([97,52])/DB,np.array([32,29])/cascades]
df_cm = pd.DataFrame(array, index = [i for i in ["True: DB","Cascade"]],
                  columns = [i for i in  ["Pred: DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm,center=0, annot=True, cmap=sn.diverging_palette(220, 100, as_cmap=True))
ax.set_ylim(0, 2)
# Out:
# (0, 2)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

DB=short_DB+Long_DB

array = [np.array([97/127,52/81]),np.array([32/127,29/81])]
df_cm = pd.DataFrame(array, index = [i for i in ["True: DB","Cascade"]],
                  columns = [i for i in  ["Pred: DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm,center=0, annot=True, cmap=sn.diverging_palette(220, 100, as_cmap=True))
ax.set_ylim(0, 2)
# Out:
# (0, 2)

# %%
49+17
# Out:
# 66

# %%
cascades=66
db=163

db_well=67
db_bad=96
cascades_well=49
cascades_bad=17

# %%
(db_well+cascades_well)/(db_well+cascades_well+db_bad+cascades_bad)
# Out:
# 0.5065502183406113

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [np.array([db_well,db_bad]),np.array([cascades_bad,cascades_well])]
df_cm = pd.DataFrame(array, index = [i for i in ["True: DB","Cascade"]],
                  columns = [i for i in  ["Pred: DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm,center=0, annot=True, cmap=sn.diverging_palette(220, 100, as_cmap=True))
ax.set_ylim(0, 2)
# Out:
# (0, 2)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [np.array([db_well,db_bad])/db,np.array([cascades_bad,cascades_well])/cascades]
df_cm = pd.DataFrame(array, index = [i for i in ["True: DB","Cascade"]],
                  columns = [i for i in  ["Pred: DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm,center=0, annot=True, cmap=sn.diverging_palette(220, 100, as_cmap=True))
ax.set_ylim(0, 2)
# Out:
# (0, 2)

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

array = [np.array([db_well/db,96/cascades]),np.array([17/db,cascades_well/cascades])]
df_cm = pd.DataFrame(array, index = [i for i in ["True: DB","Cascade"]],
                  columns = [i for i in  ["Pred: DB","Cascade"]])
plt.figure(figsize = (10,7))

ax=sn.heatmap(df_cm,center=0, annot=True, cmap=sn.diverging_palette(220, 100, as_cmap=True))
ax.set_ylim(0, 2)
# Out:
# (0, 2)

# %%
cascades_well/cascades
# Out:
# 0.7424242424242424

# %%
17/db
# Out:
# 0.10429447852760736

# %%
96/cascades
# Out:
# 1.4545454545454546
